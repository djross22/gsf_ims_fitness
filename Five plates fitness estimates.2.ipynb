# %%
import os   #operating sytem utility

import gsf_ims_fitness as fitness

# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

# %%
notebook_dir = os.getcwd()
notebook_dir
# Out:
# 'C:\\Users\\djross\\Documents\\JCloud\\GSF-IMS\\E-Coli\\pLMSF-lacI\\2019-11-04_lactose_Select-DNA-5-plates'

# %%
fitness_frame = fitness.ODFitnessFrame(notebook_dir)
# Out:
# Loading plate reader data and calculating fitness for experiment: 2019-11-04_lactose_Select-DNA-5-plates
# C:\Users\djross\anaconda3\lib\site-packages\scipy\optimize\_lsq\common.py:117: RuntimeWarning: overflow encountered in square
#   phi_prime = -np.sum(suf ** 2 / denom**3) / p_norm
# C:\Users\djross\anaconda3\lib\site-packages\scipy\optimize\_lsq\common.py:117: RuntimeWarning: overflow encountered in power
#   phi_prime = -np.sum(suf ** 2 / denom**3) / p_norm
# C:\Users\djross\anaconda3\lib\site-packages\scipy\optimize\_lsq\common.py:117: RuntimeWarning: invalid value encountered in true_divide
#   phi_prime = -np.sum(suf ** 2 / denom**3) / p_norm
# C:\Users\djross\anaconda3\lib\site-packages\scipy\optimize\_lsq\common.py:371: RuntimeWarning: invalid value encountered in greater_equal
#   return np.all((x >= lb) & (x <= ub))
# C:\Users\djross\anaconda3\lib\site-packages\scipy\optimize\_lsq\common.py:371: RuntimeWarning: invalid value encountered in less_equal
# ...

# %%
fitness_frame.plot_cell_density(y_max=0.8)

# %%
fitness_frame.plot_fitness_curves(inducer="lactose")

# %%
fitness_frame.fitness_frame
# Out:
#    well                                       density_list  \
# 0    A1  [0.5725806680839938, 0.574980853523376, 0.5201...
# 1    B1  [0.5460982341121137, 0.0348826952213952, 0.001...
# 2    C1  [0.5824444193069813, 0.5643857441769886, 0.515...
# 3    D1  [0.5578497370568274, 0.02150602934818413, 0.00...
# 4    E1  [0.5390792587430875, 0.5209771760945463, 0.513...
# ..  ...                                                ...
# 91  D12  [0.5021245373974945, 0.04947984128289229, 0.01...
# 92  E12  [0.509284083670938, 0.4923171991496005, 0.4664...
# 93  F12  [0.4652597703490067, 0.14450757452759677, 0.01...
# 94  G12  [0.49127580183183106, 0.5227259526209334, 0.46...
# 95  H12  [0.4871281783524728, 0.08344506381805816, 0.03...
#
#                                      density_err_list  inducerConcentration  \
# 0   [0.014986143833720074, 0.015584948599676386, 0...                 0.000
# 1   [0.008724332013665062, 0.005088468771733279, 0...                 0.000
# ...

# %%
fitness_frame.experiment
# Out:
# '2019-11-04_lactose_Select-DNA-5-plates'
